# %%
visualize_floorplan.py --path ../Structure3DLittle/ --scene 03005
# Out:
#   Cell In[1], line 1
#     python visualize_floorplan.py --path ../Structure3DLittle/ --scene 03005
#            ^
# SyntaxError: invalid syntax
