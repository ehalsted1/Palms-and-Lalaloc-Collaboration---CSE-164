# %%
import pytorch_lightning as pl
print("PyTorch Lightning version:", pl.__version__)
# Out:
# PyTorch Lightning version: 1.1.5

# %%
import sys
sys.path.append('./LaLaLoc')

from train import main as lalaloc_main
from omegaconf import OmegaConf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 4
#       1 import sys
#       2 sys.path.append('./LaLaLoc')
# ----> 4 from train import main as lalaloc_main
#       5 from omegaconf import OmegaConf
#
# File ~/Documents/CSE164/./LaLaLoc/train.py:8
#       5 from pytorch_lightning.callbacks import ModelCheckpoint
#       7 from lalaloc.config import get_cfg_defaults, parse_args
# ----> 8 from lalaloc.model import (
#       9     FloorPlanUnetImage,
#      10     FloorPlanUnetLayout,
#      11     ImageFromLayout,
#      12     Layout2LayoutDecode,
#      13 )
#      15 if __name__ == "__main__":
#      16     args = parse_args()
#
# File ~/Documents/CSE164/./LaLaLoc/lalaloc/model/__init__.py:1
# ----> 1 from .lalaloc import ImageFromLayout, Layout2LayoutDecode
#       2 from .lalaloc_pp import FloorPlanUnetImage, FloorPlanUnetLayout
#
# ...

# %%
# Load the configuration YAML file
config_path = '/path/to/lalaloc_repo/configs/layout_branch.yaml'
cfg = OmegaConf.load(config_path)

# Update paths manually if needed
cfg.DATASET.PATH = '/path/to/unzipped/structure3d_data'
cfg.TEST.CHECKPOINT_PATH = '/path/to/pretrained_model.ckpt'

# (optional) force CPU if you don't have a GPU
cfg.SYSTEM.NUM_GPUS = 0
